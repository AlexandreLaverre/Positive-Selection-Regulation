# %% [markdown]
# ## Import libraries and files

# %%
import pandas as pd
import warnings
import time
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import Perceptron
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

warnings.filterwarnings("ignore")
pd.set_option('display.max_colwidth', -1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import warnings
#       3 import time
# ----> 4 from xgboost import XGBClassifier
#       5 from sklearn.neural_network import MLPClassifier
#       6 from sklearn.dummy import DummyClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
def get_confusion_matrix_values(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    return(cm[0][0], cm[0][1], cm[1][0], cm[1][1])

# %%
df_output = pd.read_csv("test_file.txt")

# %%
df_output
# Out:
#                                                                                         gbif_name  \
# 0    plantae;tracheophyta;magnoliopsida;austrobaileyales;schisandraceae;illicium angustisepalum
# 1    plantae;tracheophyta;liliopsida;asparagales;orchidaceae;maxillaria calcarata
# 2    animalia;arthropoda;insecta;coleoptera;curculionidae;acalles indigens
# 3    plantae;chlorophyta;trebouxiophyceae;prasiolales;prasiolaceae;rosenvingiellopsis constricta
# 4    animalia;arthropoda;insecta;coleoptera;curculionidae;darumazo
# ..                                                              ...
# 995  plantae;tracheophyta;liliopsida;asparagales;amaryllidaceae;strumaria truncata
# 996  animalia;chordata;aves;passeriformes;alaudidae;calandrella rufescens
# 997  chromista;ochrophyta;bacillariophyceae;naviculales;scoliotropidaceae;biremis panamae
# 998  animalia;arthropoda;insecta;mantodea;nanomantidae;bolbena hottentotta
# 999  plantae;tracheophyta;magnoliopsida;ericales;ericaceae;lyonia ligustrina
#
#                                                                                          ncbi_name  \
# 0    eukaryota;streptophyta;magnoliopsida;austrobaileyales;schisandraceae;illicium angustisepalum
# 1    eukaryota;streptophyta;magnoliopsida;asparagales;orchidaceae;maxillaria calcarata
# 2    eukaryota;arthropoda;insecta;coleoptera;curculionidae;acalles indigens
# 3    eukaryota;chlorophyta;trebouxiophyceae;prasiolales;prasiolaceae;rosenvingiellopsis constricta
# 4    eukaryota;arthropoda;insecta;coleoptera;curculionidae;darumazo
# ..                                                              ...
# 995  eukaryota;streptophyta;magnoliopsida;arecales;arecaceae;phoenix canariensis
# 996  eukaryota;streptophyta;magnoliopsida;gentianales;apocynaceae;macropharynx steyermarkii
# 997  eukaryota;streptophyta;magnoliopsida;asparagales;amaryllidaceae;strumaria truncata
# 998  eukaryota;chordata;amphibia;anura;centrolenidae;nymphargus ocellatus
# 999  eukaryota;arthropoda;insecta;lepidoptera;geometridae;somatina microphylla
#
#     category_label  match  levenshtein_distance  lcs_sequence_length  \
# 0    species        1      13                    83
# 1    species        1      18                    67
# 2    species        1      9                     63
# 3    species        1      8                     87
# 4    genus          1      9                     55
# ..     ...         ..     ..                     ..
# 995  species        0      47                    43
# 996  species        0      65                    26
# 997  species        0      54                    42
# 998  species        0      53                    29
# 999  species        0      55                    32
#
#      lcs_edit_distance  damerau_levenshtein_distance  hamming_distance  \
# 0    13                 13                            87
# 1    18                 18                            74
# 2    9                  9                             69
# 3    8                  8                             88
# 4    9                  9                             62
# ..  ..                 ..                             ..
# 995  47                 47                            71
# 996  65                 65                            79
# 997  54                 54                            76
# 998  53                 52                            66
# 999  55                 54                            68
#
#      jaro_similarity  ...  partial_ratio  token_sort_ratio  token_set_ratio  \
# 0    0.823248         ...  92             87                91
# 1    0.820198         ...  86             80                80
# 2    0.848677         ...  91             86                93
# 3    0.895616         ...  96             95                95
# 4    0.852004         ...  89             85                92
# ..        ...         ...  ..             ..                ..
# 995  0.712099         ...  57             50                50
# 996  0.666758         ...  38             38                38
# 997  0.683051         ...  51             45                45
# 998  0.650400         ...  43             44                44
# 999  0.711520         ...  45             44                44
#
#      w_ratio  uq_ratio  q_ratio  matching_numbers  matching_numbers_log  \
# 0    91       91        91       1                 0.693147
# 1    85       85        85       1                 0.693147
# 2    91       91        91       1                 0.693147
# 3    95       95        95       1                 0.693147
# 4    89       89        89       1                 0.693147
# ..   ..       ..        ..      ..                      ...
# 995  57       57        57       1                 0.693147
# 996  36       34        34       1                 0.693147
# 997  51       51        51       1                 0.693147
# 998  42       42        42       1                 0.693147
# 999  44       44        44       1                 0.693147
#
#      log_fuzz_score  log_fuzz_score_numbers
# 0    5.888878        5.888878
# 1    5.802118        5.802118
# 2    5.886104        5.886104
# 3    5.940171        5.940171
# 4    5.872118        5.872118
# ..        ...             ...
# 995  5.361292        5.361292
# 996  4.997212        4.997212
# 997  5.252273        5.252273
# 998  5.153292        5.153292
# 999  5.176150        5.176150
#
# [1000 rows x 23 columns]

# %% [markdown]
# ## Feature selection (find features that the most contribute to the prediction)

# %%
#Correlation with output variable
cor_target = abs(df_output.corr()["match"])
#Selecting highly correlated features
relevant_features = list(pd.DataFrame(cor_target[cor_target>0.9]).index)

# %%
features = pd.DataFrame(cor_target[cor_target>0.9]).sort_values("match", ascending=False)

# %%
top_feature_list = list(features.head()[1:].index)

# %% [markdown]
# ## Find best classifiers for the prediction

# %%
#creating training and testing data
X = df_output[relevant_features[1:]].values
y = df_output['match'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
#selecting and comparing state of the art classifiers to choose the best one
classifiers = {
    "DummyClassifier_stratified":DummyClassifier(strategy='stratified', random_state=0),    
    "KNeighborsClassifier":KNeighborsClassifier(3),
    "DecisionTreeClassifier":DecisionTreeClassifier(),
    "AdaBoostClassifier":AdaBoostClassifier(),
    "GradientBoostingClassifier":GradientBoostingClassifier(),
    "Perceptron": Perceptron(max_iter=40, eta0=0.1, random_state=1),
    "SupportVectorMachine":SVC(),
    "MLP": MLPClassifier(max_iter=100),
    "RandomForestClassifier":RandomForestClassifier(),
    "XGBClassifier":XGBClassifier(n_estimators=1000, learning_rate=0.1),
    "XGBClassifier finetuned":XGBClassifier(
                      scale_pos_weight=1,
                      learning_rate=0.01,  
                      colsample_bytree = 0.8,
                      subsample = 0.8,
                      objective='binary:logistic', 
                      n_estimators=1000, 
                      reg_alpha = 0.3,
                      max_depth=9, 
                      gamma=10)

}

df_results = pd.DataFrame(columns=['model', 'accuracy', 'mae', 'precision','recall','f1','roc','run_time','tp','fp','tn','fn'])
for key in classifiers:

    start_time = time.time()
    classifier = classifiers[key]
    model = classifier.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, zero_division=0)
    roc = roc_auc_score(y_test, y_pred)
    classification = classification_report(y_test, y_pred, zero_division=0)
    run_time = format(round((time.time() - start_time)/60,2))
    tp, fp, fn, tn = get_confusion_matrix_values(y_test, y_pred)

    row = {'model': key,
           'accuracy': accuracy,
           'mae': mae,
           'precision': precision,
           'recall': recall,
           'f1': f1,
           'roc': roc,
           'run_time': run_time,
           'tp': tp,
           'fp': fp,
           'tn': tn,
           'fn': fn,
          }
    df_results = df_results.append(row, ignore_index=True)

df_results.sort_values(['accuracy', 'precision'], ascending=[False, False]).reset_index(drop = True)
# Out:
#                          model  accuracy       mae  precision    recall  \
# 0   DecisionTreeClassifier      1.000000  0.000000  1.000000   1.000000
# 1   AdaBoostClassifier          1.000000  0.000000  1.000000   1.000000
# 2   GradientBoostingClassifier  1.000000  0.000000  1.000000   1.000000
# 3   SupportVectorMachine        1.000000  0.000000  1.000000   1.000000
# 4   RandomForestClassifier      1.000000  0.000000  1.000000   1.000000
# 5   XGBClassifier               1.000000  0.000000  1.000000   1.000000
# 6   XGBClassifier finetuned     1.000000  0.000000  1.000000   1.000000
# 7   KNeighborsClassifier        0.996667  0.003333  1.000000   0.993421
# 8   Perceptron                  0.993333  0.006667  1.000000   0.986842
# 9   MLP                         0.993333  0.006667  0.993421   0.993421
# 10  DummyClassifier_stratified  0.463333  0.536667  0.468966   0.447368
#
#           f1       roc run_time   tp  fp   tn  fn
# 0   1.000000  1.000000  0.0      148  0   152  0
# 1   1.000000  1.000000  0.0      148  0   152  0
# 2   1.000000  1.000000  0.0      148  0   152  0
# 3   1.000000  1.000000  0.0      148  0   152  0
# 4   1.000000  1.000000  0.0      148  0   152  0
# 5   1.000000  1.000000  0.0      148  0   152  0
# 6   1.000000  1.000000  0.0      148  0   152  0
# 7   0.996700  0.996711  0.0      148  0   151  1
# 8   0.993377  0.993421  0.0      148  0   150  2
# 9   0.993421  0.993332  0.0      147  1   151  1
# 10  0.457912  0.463549  0.0      71   77  68   84
